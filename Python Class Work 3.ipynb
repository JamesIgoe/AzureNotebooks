# %%
#%matplotlib notebook
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o')
plt.ylabel('Y')
plt.xlabel('X')
plt.show()

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
# !pip install --upgrade pip
# !pip install xlrd
# Out:
# Requirement already up-to-date: pip in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (20.2.1)
# ...

# %%
df_canada = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                          sheet_name='Canada by Citizenship',
                          skiprows=range(20), 
                          skipfooter=2)
df_canada.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...   2004  2005  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...   1816  1852
# 191     Northern Africa  902  Developing regions     0  ...      0     0
# 192        Western Asia  902  Developing regions     1  ...    124   161
# 193      Eastern Africa  902  Developing regions    11  ...     56    91
# 194      Eastern Africa  902  Developing regions    72  ...   1450   615
#
#      2006  2007  2008  2009  2010  2011  2012  2013
# 190  3153  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
df_canada.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...   2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...   2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...   1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...   3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...      0     0     1
# 4  Southern Europe  901   Developed regions     0  ...      0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
# Type        195 non-null object
# Coverage    195 non-null object
# OdName      195 non-null object
# AREA        195 non-null int64
# AreaName    195 non-null object
# REG         195 non-null int64
# RegName     195 non-null object
# DEV         195 non-null int64
# DevName     195 non-null object
# 1980        195 non-null int64
# 1981        195 non-null int64
# 1982        195 non-null int64
# 1983        195 non-null int64
# 1984        195 non-null int64
# 1985        195 non-null int64
# 1986        195 non-null int64
# 1987        195 non-null int64
# 1988        195 non-null int64
# 1989        195 non-null int64
# 1990        195 non-null int64
# 1991        195 non-null int64
# 1992        195 non-null int64
# 1993        195 non-null int64
# 1994        195 non-null int64
# 1995        195 non-null int64
# 1996        195 non-null int64
# ...

# %%
df_canada.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
df_canada.describe(include='object')
# Out:
#               Type    Coverage   OdName AreaName       RegName  \
# count          195         195      195      195           195
# unique           1           2      195        6            22
# top     Immigrants  Foreigners  Croatia   Africa  Western Asia
# freq           195         194        1       54            18
#
#                    DevName
# count                  195
# unique                   2
# top     Developing regions
# freq                   147

# %%
df_canada.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df_canada.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013], dtype=object)

# %%
df_canada.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
df_canada.shape
# Out:
# (195, 43)

# %%
df_canada.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# %%
df_canada.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_canada.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_canada['Total'] = df_canada.sum(axis=1)

# %%
df_canada.isnull().sum()
# Out:
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
df_canada.Country
# Out:
# 0                                            Afghanistan
# 1                                                Albania
# 2                                                Algeria
# 3                                         American Samoa
# 4                                                Andorra
# 5                                                 Angola
# 6                                    Antigua and Barbuda
# 7                                              Argentina
# 8                                                Armenia
# 9                                              Australia
# 10                                               Austria
# 11                                            Azerbaijan
# 12                                               Bahamas
# 13                                               Bahrain
# 14                                            Bangladesh
# 15                                              Barbados
# ...

# %%
df_canada[['Country', 1980, 1981, 1982, 1983, 1984, 1985]]
# Out:
#                                                Country   1980   1981   1982  \
# 0                                          Afghanistan     16     39     39
# 1                                              Albania      1      0      0
# 2                                              Algeria     80     67     71
# 3                                       American Samoa      0      1      0
# 4                                              Andorra      0      0      0
# 5                                               Angola      1      3      6
# 6                                  Antigua and Barbuda      0      0      0
# 7                                            Argentina    368    426    626
# 8                                              Armenia      0      0      0
# 9                                            Australia    702    639    484
# 10                                             Austria    234    238    201
# ...

# %%
df_canada.set_index('Country', inplace=True)

# %%
df_canada.index.name = 'Country'

# %%
df_canada.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...    2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...    3436  3009  2652  2111
# Albania            0     0     0     0     1  ...    1223   856   702   560
# Algeria           71    69    63    44    69  ...    3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...       0     1     0     0
# Andorra            0     0     0     0     2  ...       0     1     1     0
#
# ...

# %%
df_canada.loc['Japan']
# Out:
# Continent                 Asia
# Region            Eastern Asia
# DevName      Developed regions
# 1980                       701
# 1981                       756
# 1982                       598
# 1983                       309
# 1984                       246
# 1985                       198
# 1986                       248
# 1987                       422
# 1988                       324
# 1989                       494
# 1990                       379
# 1991                       506
# 1992                       605
# 1993                       907
# 1994                       956
# 1995                       826
# 1996                       994
# 1997                       924
# 1998                       897
# 1999                      1083
# 2000                      1010
# 2001                      1092
# 2002                       806
# 2003                       817
# 2004                       973
# 2005                      1067
# 2006                      1212
# ...

# %%
df_canada.loc['Japan',2013]
# Out:
# 982

# %%
df_canada.loc['Japan',[1990, 2000, 2010]]
# Out:
# 1990     379
# 2000    1010
# 2010    1168
# Name: Japan, dtype: object

# %%
year_range = [1990, 2000, 2010]
df_canada.loc['Japan',year_range]
# Out:
# 1990     379
# 2000    1010
# 2010    1168
# Name: Japan, dtype: object

# %%
year_range = range(1990, 2010)
df_canada.loc['Japan',year_range]
# Out:
# 1990     379
# 1991     506
# 1992     605
# 1993     907
# 1994     956
# 1995     826
# 1996     994
# 1997     924
# 1998     897
# 1999    1083
# 2000    1010
# 2001    1092
# 2002     806
# 2003     817
# 2004     973
# 2005    1067
# 2006    1212
# 2007    1250
# 2008    1284
# 2009    1194
# Name: Japan, dtype: object

# %%
df_canada.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...    2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...    3436  3009  2652  2111
# Albania            0     0     0     0     1  ...    1223   856   702   560
# Algeria           71    69    63    44    69  ...    3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...       0     1     0     0
# Andorra            0     0     0     0     2  ...       0     1     1     0
#
# ...

# %%
mpl.__version__
# Out:
# '3.0.0'

# %%
plt.style.available
# Out:
# ['seaborn-colorblind',
#  'seaborn-talk',
#  'seaborn',
#  'fast',
#  'seaborn-darkgrid',
#  'ggplot',
#  'classic',
#  'bmh',
#  'seaborn-ticks',
#  'seaborn-white',
#  '_classic_test',
#  'seaborn-dark-palette',
#  'grayscale',
#  'seaborn-poster',
#  'tableau-colorblind10',
#  'seaborn-deep',
#  'seaborn-bright',
#  'seaborn-whitegrid',
#  'fivethirtyeight',
#  'seaborn-muted',
#  'dark_background',
#  'seaborn-notebook',
#  'seaborn-dark',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'Solarize_Light2']

# %%
mpl.style.use(['ggplot'])

# %%
year_range = range(1980, 2015)
df_haiti = df_canada.loc['Haiti', year_range]
df_haiti.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexing.py:1027: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return getattr(section, self.name)[new_key]
# 1980    1666
# 1981    3692
# 1982    3498
# 1983    2860
# 1984    1418
# Name: Haiti, dtype: object

# %%
df_haiti.plot()

# %%
df_haiti.index = df_haiti.index.map(int)
df_haiti.plot(kind='line')
plt.title('simple immigration plot on Haiti')
plt.ylabel('number of immigrants')
plt.xlabel('years')
plt.show()

# %%
df_haiti.index = df_haiti.index.map(int)
df_haiti.plot(kind='line')
plt.title('simple immigration plot on Haiti')
plt.ylabel('number of immigrants')
plt.xlabel('years')
plt.text(2000,6000,'2010 earthquake')
plt.show()

# %%
df_china = df_canada.loc['China', year_range]
df_india = df_canada.loc['India', year_range]
df_CI = df_canada.loc[['China', 'India'], year_range]
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   app.launch_new_instance()

# %%
df_china.plot()

# %%
df_india.plot()

# %%
df_CI.plot(kind='line')
plt.title('China vs India')
plt.ylabel('Immigrants')
plt.xlabel('Years')
plt.show()

# %%
df_CI_transpose = df_CI.transpose()
df_CI_transpose.plot(kind='line')
plt.title('China vs India')
plt.ylabel('Immigrants')
plt.xlabel('Years')
plt.show()

# %%
#get five larget countries, using total column
df_canada['Total'].max()
# Out:
# 691904

# %%
df_canada.nlargest(5,['Total'])
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
df_largest = df_canada.nlargest(5,['Total'])
#df_largest.head()
df_plot = df_largest.loc[['Pakistan','India','China','United Kingdom of Great Britain and Northern Ireland','Philippines'], year_range]
df_plot.transpose().plot()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   app.launch_new_instance()

# %%
df_plot = df_largest.loc[df_largest.index, year_range]
df_plot.transpose().plot()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   if __name__ == '__main__':

# %%
#df_canada.info()
df_canada.sort_values(['Total'], ascending=False, axis=0, inplace=True)

# %%
df_canada.head()
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
df_canada_top5 = df_canada.head()
df_canada_top5
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
df_top5_plot = df_canada_top5.loc[df_canada_top5.index, year_range].transpose()
df_top5_plot
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   if __name__ == '__main__':
# Country    India    China  \
# 1980      8880.0   5123.0
# 1981      8670.0   6682.0
# 1982      8147.0   3308.0
# 1983      7338.0   1863.0
# 1984      5704.0   1527.0
# 1985      4211.0   1816.0
# 1986      7150.0   1960.0
# 1987     10189.0   2643.0
# 1988     11522.0   2758.0
# 1989     10343.0   4323.0
# 1990     12041.0   8076.0
# 1991     13734.0  14255.0
# 1992     13673.0  10846.0
# 1993     21496.0   9817.0
# 1994     18620.0  13128.0
# 1995     18489.0  14398.0
# 1996     23859.0  19415.0
# 1997     22268.0  20475.0
# 1998     17241.0  21049.0
# 1999     18974.0  30069.0
# ...

# %%
df_top5_plot.plot(kind="area", figsize=(20,10))
plt.title("area plot for top 5 immigation countries to Cancada")
plt.ylabel("number of immigrants")
plt.xlabel("year")
plt.show()

# %%
df_canada[2013].plot(kind="hist")
plt.title("histogram of immigration to Cancada in 2013")
plt.ylabel("number of countries")
plt.xlabel("number of immigrants")
plt.show()

# %%
count, bin_edges = np.histogram(df_canada[2013])

df_canada[2013].plot(kind="hist", xticks = bin_edges)

plt.title("histogram of immigration to Cancada in 2013")
plt.ylabel("number of countries")
plt.xlabel("number of immigrants")
plt.show()

# %%
df_iceland = df_canada.loc['Iceland', year_range]
df_iceland.plot(kind="bar")

plt.title("bar chart of immigration from Iceland to Cancada")
plt.ylabel("Year")
plt.xlabel("Number")
plt.show()

# %%
df_top5_plot.plot(kind="area", stacked=False, figsize=(20,10), alpha=0.25)
plt.title("area plot for top 5 immigation countries to Cancada")
plt.ylabel("number of immigrants")
plt.xlabel("year")
plt.show()

# %%
ax = df_top5_plot.plot(kind="area", stacked=True, figsize=(20,10), alpha=0.25)
ax.set_title("area plot for top 5 immigation countries to Cancada")
ax.set_ylabel("number of immigrants")
ax.set_xlabel("year")
# Out:
# Text(0.5, 0, 'year')

# %%
df_smallest = df_canada.nsmallest(5,['Total'])
year_range = range(1980,  2013)
df_smallest_plot = df_smallest.loc[df_smallest.index, year_range].transpose()
ax = df_smallest_plot.plot(kind="area", stacked=True, figsize=(20,10), alpha=0.45)
ax.set_title("area plot for bottom 5 immigation countries to Canada")
ax.set_ylabel("number of immigrants")
ax.set_xlabel("year")
# Out:
# Text(0.5, 0, 'year')

# %%
ax = df_smallest_plot.plot(kind="area", stacked=False, figsize=(20,10), alpha=0.55)
ax.set_title("area plot for bottom 5 immigation countries to Canada")
ax.set_ylabel("number of immigrants")
ax.set_xlabel("year")
# Out:
# Text(0.5, 0, 'year')

# %%
df_t = df_canada.loc[['Greece', 'Albania', 'Bulgaria'], year_range].transpose()
df_t.head()
# Out:
# Country  Greece  Albania  Bulgaria
# 1980       1065        1        24
# 1981        953        0        20
# 1982        897        0        12
# 1983        633        0        33
# 1984        580        0        11

# %%
count, bin_edges = np.histogram(df_t, 15)
xmin = bin_edges[0] - 10
xmax = bin_edges[-1] + 10

# stacked Histogram
df_t.plot(kind='hist',
          figsize=(10, 6), 
          bins=15,
          xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen'],
          stacked=False,
          xlim=(xmin, xmax),
          alpha=0.35          
         )

plt.title('Histogram of Immigration from Greece, Albania, Bulgaria from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants') 

plt.show()

# %%
df_iceland.plot(kind="bar", figsize=(10,6), rot=90)

plt.title("bar chart of immigration from Iceland to Cancada")
plt.ylabel("Year")
plt.xlabel("Number")

plt.annotate('',                      # s: str. will leave it blank for no text
             xy=(32, 65),             # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 24),         # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',         # will use the coordinate system of the object being annotated 
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )

plt.annotate('2008 - 2011 Financial Crisis', # text to display
             xy=(28, 32),                    # start the text at at point (year 2008 , pop 30)
             rotation=70,                  # based on trial and error to match the arrow
             va='bottom',                    # want the text to be vertically 'bottom' aligned
             ha='left',                      # want the text to be horizontally 'left' algned.
            )

plt.show()

# %%
df_top15 = df_canada.nlargest(15, ['Total'])
df_top15.head()
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
df_top15_plot = df_top15.loc[df_top15.index, 'Total']
df_top15_plot.plot(kind="barh", figsize=(20,10))
plt.title("hbar chart of top 15 immigration countries to Cancada")
plt.ylabel("Year")
plt.xlabel("Number")
plt.show()
